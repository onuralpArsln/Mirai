# %% [markdown]
# # Demo Version

# %%
#  General Prep  Made Here

import cv2
import time

from keras.models import load_model  # TensorFlow is required for Keras to work
from PIL import Image, ImageOps  # Install pillow instead of PIL
import numpy as np
# pip install tensorflow==2.12.1 

# Disable scientific notation for clarity
np.set_printoptions(suppress=True)
# Load the model
model = load_model("keras_model.h5", compile=False)
# Load the labels
class_names = open("labels.txt", "r").readlines()

# Create the array of the right shape to feed into the keras model
# The 'length' or number of images you can put into the array is
# determined by the first position in the shape tuple, in this case 1
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)


# Load the pre-trained Haar Cascade for face detection
cascade_path = 'haarcascade_frontalface_default.xml'
face_cascade = cv2.CascadeClassifier(cascade_path)

# Check if the cascade file is loaded correctly
if face_cascade.empty():
    raise IOError(f"Failed to load cascade classifier from {cascade_path}")

# Create a video capture object
cap = cv2.VideoCapture(0)  # 0 for the default camera

# Check if the webcam is opened correctly
if not cap.isOpened():
    raise ValueError("Unable to open video source")

# Define fixed window size for cropped face display
fixed_window_size = (224, 224)  # Width, Height

# Desired frame rate
desired_fps = 10
frame_duration = 1 / desired_fps  # Duration of each frame in seconds

# Define text parameters
text_size = 0.8  # Change this value to increase or decrease text size
text_color = (0, 255, 0)  # Text color in BGR format (Green)
text_thickness = 2  # Thickness of the text stroke
shadow_color = (0, 0, 0)  # Shadow color in BGR format (Black)
shadow_offset = (0, 0)  # Offset for shadow position



try:
    while True:
        start_time = time.time()  # Start time of the loop

        # Capture frame-by-frame
        ret, frame = cap.read()  # ret is a boolean, frame is the captured image

        if not ret:  # Check if the frame was captured successfully
            print("Failed to capture image")
            break

        # Convert frame to grayscale for face detection
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        # Detect faces in the frame
        faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

        # Draw a rectangle around each face and crop the face
        for (x, y, w, h) in faces:
            cv2.rectangle(frame, (x, y), (x + w, y + h), (255, 0, 0), 2)
            
            # Crop the face region
            face_crop = frame[y:y + h, x:x + w]

            # Resize the cropped face to the fixed window size
            face_crop_resized = cv2.resize(face_crop, fixed_window_size)

            # Add shadow text to the cropped face window
         
            font = cv2.FONT_HERSHEY_SIMPLEX
            # Calculate text size for shadow
            (text_width, text_height), baseline = cv2.getTextSize(text, font, text_size, text_thickness)
            text_x, text_y = 10, 30  # Position for the text
            shadow_x, shadow_y = text_x + shadow_offset[0], text_y + shadow_offset[1]

            ##########  
            # Replace this with the path to your image
            file_path="img.jpg"
            cv2.imwrite(file_path, face_crop_resized)
            image = Image.open(file_path).convert("RGB")

            # resizing the image to be at least 224x224 and then cropping from the center
            size = (224, 224)
            image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)

            # turn the image into a numpy array
            image_array = np.asarray(image)

            # Normalize the image
            normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1

            # Load the image into the array
            data[0] = normalized_image_array

            # Predicts the model
            prediction = model.predict(data)
            index = np.argmax(prediction)
            class_name = class_names[index]
            confidence_score = prediction[0][index]

            # Print prediction and confidence score
            print("Class:", class_name[2:], end="")
            print("Confidence Score:", confidence_score)
            guess=f"{class_name[2:]}:{confidence_score}"

            ##########

            # Draw the shadow (background rectangle)
            cv2.rectangle(face_crop_resized, (shadow_x, shadow_y - text_height), (shadow_x + text_width, shadow_y + baseline), shadow_color, thickness=cv2.FILLED)
            # Draw the text
            cv2.putText(face_crop_resized, guess, (text_x, text_y), font, text_size, text_color, text_thickness, cv2.LINE_AA)

            # Display the cropped face in a separate window
            cv2.imshow('Cropped Face', face_crop_resized)
            # Ensure the window size is fixed
            cv2.resizeWindow('Cropped Face', fixed_window_size[0], fixed_window_size[1])

        # Add shadow text to the main video window
        main_text = 'Press "q" to exit'
        second_text = 'Second Line'
        (text_width, text_height), baseline = cv2.getTextSize(main_text, font, text_size, text_thickness)
        text_x, text_y = 10, 30  # Position for the text
        shadow_x, shadow_y = text_x + shadow_offset[0], text_y + shadow_offset[1]

        # Draw the shadow (background rectangle)
        cv2.rectangle(frame, (shadow_x, shadow_y - text_height), (shadow_x + text_width, shadow_y*2 + baseline), shadow_color, thickness=cv2.FILLED)
        # Draw the text
        cv2.putText(frame, main_text, (text_x, text_y), font, text_size, text_color, text_thickness, cv2.LINE_AA)
        
        # second text
        cv2.putText(frame, second_text, (text_x, text_y*2), font, text_size, text_color, text_thickness, cv2.LINE_AA)

        # Display the resulting frame in a window named 'Video'
        cv2.imshow('Video', frame)

        # Calculate the time taken for one loop iteration
        elapsed_time = time.time() - start_time
        # Calculate the delay needed to maintain the desired frame rate
        delay = max(1, int((frame_duration - elapsed_time) * 1000))
        
        # Break the loop if 'q' key is pressed
        if cv2.waitKey(delay) & 0xFF == ord('q'):
            break

except KeyboardInterrupt:
    pass
finally:
    # Release the capture and close windows
    cap.release()
    cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 1s 701ms/step
# Class: neutral
# Confidence Score: 0.9953211
# 1/1 [==============================] - 0s 25ms/step
# Class: happy
# Confidence Score: 0.9430729
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.6792857
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.9965731
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.98260844
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.9922672
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.9993742
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.98829067
# 1/1 [==============================] - 0s 27ms/step
# Class: neutral
# Confidence Score: 0.9991714
# 1/1 [==============================] - 0s 30ms/step
# Class: neutral
# Confidence Score: 0.99678147
# 1/1 [==============================] - 0s 29ms/step
# Class: happy
# Confidence Score: 0.9618673
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.8166743
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.9959721
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.99327564
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.9994342
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.9975115
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.99414355
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.9984257
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.99510974
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.9901163
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.99898237
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.9707727
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.99490273
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.9971349
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.9993498
# 1/1 [==============================] - 0s 34ms/step
# Class: neutral
# Confidence Score: 0.99762493
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.9834063
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.95566297
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.9634242
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.9799905
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.98452145
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.99582267
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.927718
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.8951505
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.90196806
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.98904616
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.95298344
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.9657701
# 1/1 [==============================] - 0s 21ms/step
# Class: neutral
# Confidence Score: 0.99216473
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.99439937
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.99369806
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.9902638
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.99552816
# 1/1 [==============================] - 0s 31ms/step
# Class: neutral
# Confidence Score: 0.99776447
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.99763644
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.99795085
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.9954822
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.9947352
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.9963722
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.99922526
# 1/1 [==============================] - 0s 27ms/step
# Class: neutral
# Confidence Score: 0.9956772
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.99948335
# 1/1 [==============================] - 0s 20ms/step
# Class: neutral
# Confidence Score: 0.9991436
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.99367887
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.9939428
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.97644913
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.99106103
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.9985262
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.99737275
# 1/1 [==============================] - 0s 25ms/step
# Class: happy
# Confidence Score: 0.7939511
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.6464713
# 1/1 [==============================] - 0s 23ms/step
# Class: surprise
# Confidence Score: 0.5468995
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.94157135
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.9982919
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.9996043
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.9992975
# 1/1 [==============================] - 0s 23ms/step
# Class: happy
# Confidence Score: 0.64137703
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.74602956
# 1/1 [==============================] - 0s 21ms/step
# Class: neutral
# Confidence Score: 0.9998591
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.99838114
# 1/1 [==============================] - 0s 22ms/step
# Class: happy
# Confidence Score: 0.6693983
# 1/1 [==============================] - 0s 22ms/step
# Class: surprise
# Confidence Score: 0.6315044
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.9845841
# 1/1 [==============================] - 0s 22ms/step
# Class: surprise
# Confidence Score: 0.5614261
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.8141808
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.9984289
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.9986016
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.99960154
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.99802184
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.9965862
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.9940666
# 1/1 [==============================] - 0s 23ms/step
# Class: surprise
# Confidence Score: 0.80975246
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.8762444
# 1/1 [==============================] - 0s 23ms/step
# Class: surprise
# Confidence Score: 0.5952551
# 1/1 [==============================] - 0s 23ms/step
# Class: surprise
# Confidence Score: 0.5499326
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.9997992
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.99058086
# 1/1 [==============================] - 0s 23ms/step
# Class: angry
# Confidence Score: 0.46175703
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.51623565
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.9561634
# 1/1 [==============================] - 0s 25ms/step
# Class: happy
# Confidence Score: 0.7676898
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.6550885
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.96061194
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.99330646
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.37474588
# 1/1 [==============================] - 0s 24ms/step
# Class: angry
# Confidence Score: 0.7477575
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.9970579
# 1/1 [==============================] - 0s 29ms/step
# Class: happy
# Confidence Score: 0.870737
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.37758416
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.98644626
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.9661524
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.9814456
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.99493057
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.9858629
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.9982253
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.96536523
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.9920014
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.9981614
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.99432784
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.9954535
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.9948095
# 1/1 [==============================] - 0s 22ms/step
# Class: angry
# Confidence Score: 0.8393457
# 1/1 [==============================] - 0s 22ms/step
# Class: angry
# Confidence Score: 0.5809248
# 1/1 [==============================] - 0s 21ms/step
# Class: neutral
# Confidence Score: 0.9964271
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.97537166
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.99877185
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.9952981
# 1/1 [==============================] - 0s 30ms/step
# Class: neutral
# Confidence Score: 0.96324944
# 1/1 [==============================] - 0s 30ms/step
# Class: neutral
# Confidence Score: 0.9963122
# 1/1 [==============================] - 0s 34ms/step
# Class: neutral
# Confidence Score: 0.97436655
# 1/1 [==============================] - 0s 29ms/step
# Class: neutral
# Confidence Score: 0.99782085
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.9946472
# 1/1 [==============================] - 0s 28ms/step
# Class: neutral
# Confidence Score: 0.99750817
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.98559475
# 1/1 [==============================] - 0s 27ms/step
# Class: happy
# Confidence Score: 0.57495105
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.49595168
# 1/1 [==============================] - 0s 23ms/step
# Class: angry
# Confidence Score: 0.49017307
# 1/1 [==============================] - 0s 24ms/step
# Class: angry
# Confidence Score: 0.6305793
# 1/1 [==============================] - 0s 21ms/step
# Class: neutral
# Confidence Score: 0.99013114
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.9942503
# 1/1 [==============================] - 0s 27ms/step
# Class: neutral
# Confidence Score: 0.9954419
# 1/1 [==============================] - 0s 25ms/step
# Class: angry
# Confidence Score: 0.9540911
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.9038916
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.9957877
# 1/1 [==============================] - 0s 23ms/step
# Class: angry
# Confidence Score: 0.6350042
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.65698504
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.9971961
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.9717936
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.9956055
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.9964474
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.99288744
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.99429625
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.9847995
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.97889006
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.98864156
# 1/1 [==============================] - 0s 24ms/step
# Class: happy
# Confidence Score: 0.82220376
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.8670477
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.9856784
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.9920398
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.8279729
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.93126726
# 1/1 [==============================] - 0s 36ms/step
# Class: neutral
# Confidence Score: 0.95602405
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.98029536
# 1/1 [==============================] - 0s 31ms/step
# Class: neutral
# Confidence Score: 0.97149265
# 1/1 [==============================] - 0s 32ms/step
# Class: neutral
# Confidence Score: 0.9845598
# 1/1 [==============================] - 0s 30ms/step
# Class: neutral
# Confidence Score: 0.91889995
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.9396975
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.98114806
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.99453354
# 1/1 [==============================] - 0s 24ms/step
# Class: happy
# Confidence Score: 0.9078968
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.76334596
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.99953294
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.9945357
# 1/1 [==============================] - 0s 28ms/step
# Class: neutral
# Confidence Score: 0.99936324
# 1/1 [==============================] - 0s 31ms/step
# Class: neutral
# Confidence Score: 0.9996598
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.9993525
# 1/1 [==============================] - 0s 30ms/step
# Class: neutral
# Confidence Score: 0.9985329
# 1/1 [==============================] - 0s 29ms/step
# Class: neutral
# Confidence Score: 0.99268794
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.99939454
# 1/1 [==============================] - 0s 24ms/step
# Class: happy
# Confidence Score: 0.7035024
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.90900743
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.9971726
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.9961035
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.99131775
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.926287
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.9099168
# 1/1 [==============================] - 0s 50ms/step
# Class: neutral
# Confidence Score: 0.91850966
# 1/1 [==============================] - 0s 32ms/step
# Class: neutral
# Confidence Score: 0.98294616
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.9801608
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.9528885
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.9222339
# 1/1 [==============================] - 0s 29ms/step
# Class: neutral
# Confidence Score: 0.84153366
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.9283532
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.9291257
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.928726
# 1/1 [==============================] - 0s 24ms/step
# Class: happy
# Confidence Score: 0.9906832
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.7599338
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.8611991
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.9103797
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.994689
# 1/1 [==============================] - 0s 27ms/step
# Class: neutral
# Confidence Score: 0.72912645
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.9197462
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.91342056
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.9684919
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.9177382
# 1/1 [==============================] - 0s 27ms/step
# Class: neutral
# Confidence Score: 0.9907583
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.895325
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.9884291
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.9987801
# 1/1 [==============================] - 0s 34ms/step
# Class: neutral
# Confidence Score: 0.97554624
# 1/1 [==============================] - 0s 29ms/step
# Class: neutral
# Confidence Score: 0.9953485
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.94242245
# 1/1 [==============================] - 0s 28ms/step
# Class: neutral
# Confidence Score: 0.9938013
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.9922011
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.99915504
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.95816267
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.999201
# 1/1 [==============================] - 0s 32ms/step
# Class: neutral
# Confidence Score: 0.99607456
# 1/1 [==============================] - 0s 30ms/step
# Class: neutral
# Confidence Score: 0.95958644
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.94079477
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.99098223
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.977662
# 1/1 [==============================] - 0s 27ms/step
# Class: neutral
# Confidence Score: 0.97038496
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.99557906
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.99281454
# 1/1 [==============================] - 0s 29ms/step
# Class: neutral
# Confidence Score: 0.9986533
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.9236002
# 1/1 [==============================] - 0s 27ms/step
# Class: neutral
# Confidence Score: 0.98211795
# 1/1 [==============================] - 0s 27ms/step
# Class: neutral
# Confidence Score: 0.99305576
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.9992748
# 1/1 [==============================] - 0s 25ms/step
# Class: angry
# Confidence Score: 0.85828376
# 1/1 [==============================] - 0s 36ms/step
# Class: angry
# Confidence Score: 0.639598
# 1/1 [==============================] - 0s 25ms/step
# Class: angry
# Confidence Score: 0.9353181
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.87124234
# 1/1 [==============================] - 0s 31ms/step
# Class: neutral
# Confidence Score: 0.9991278
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.9955615
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.99883085
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.9991862
# 1/1 [==============================] - 0s 23ms/step
# Class: happy
# Confidence Score: 0.96320784
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.847764
# 1/1 [==============================] - 0s 27ms/step
# Class: neutral
# Confidence Score: 0.9816952
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.40997294
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.93893564
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.36355087
# 1/1 [==============================] - 0s 23ms/step
# Class: surprise
# Confidence Score: 0.8914879
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.7745491
# 1/1 [==============================] - 0s 27ms/step
# Class: neutral
# Confidence Score: 0.79137176
# 1/1 [==============================] - 0s 25ms/step
# Class: surprise
# Confidence Score: 0.8187668
# 1/1 [==============================] - 0s 27ms/step
# Class: surprise
# Confidence Score: 0.9542512
# 1/1 [==============================] - 0s 25ms/step
# Class: surprise
# Confidence Score: 0.81828374
# 1/1 [==============================] - 0s 24ms/step
# Class: surprise
# Confidence Score: 0.76732755
# 1/1 [==============================] - 0s 24ms/step
# Class: surprise
# Confidence Score: 0.65310496
# 1/1 [==============================] - 0s 23ms/step
# Class: surprise
# Confidence Score: 0.7315612
# 1/1 [==============================] - 0s 25ms/step
# Class: surprise
# Confidence Score: 0.5519927
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.70304203
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.73025876
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.5936408
# 1/1 [==============================] - 0s 25ms/step
# Class: surprise
# Confidence Score: 0.68173987
# 1/1 [==============================] - 0s 25ms/step
# Class: surprise
# Confidence Score: 0.87313056
# 1/1 [==============================] - 0s 24ms/step
# Class: surprise
# Confidence Score: 0.903248
# 1/1 [==============================] - 0s 25ms/step
# Class: surprise
# Confidence Score: 0.9372287
# 1/1 [==============================] - 0s 27ms/step
# Class: surprise
# Confidence Score: 0.7375743
# 1/1 [==============================] - 0s 31ms/step
# Class: surprise
# Confidence Score: 0.7714123
# 1/1 [==============================] - 0s 32ms/step
# Class: surprise
# Confidence Score: 0.7471854
# 1/1 [==============================] - 0s 27ms/step
# Class: surprise
# Confidence Score: 0.57513046
# 1/1 [==============================] - 0s 24ms/step
# Class: surprise
# Confidence Score: 0.7661202
# 1/1 [==============================] - 0s 23ms/step
# Class: surprise
# Confidence Score: 0.75943464
# 1/1 [==============================] - 0s 24ms/step
# Class: surprise
# Confidence Score: 0.8537877
# 1/1 [==============================] - 0s 25ms/step
# Class: surprise
# Confidence Score: 0.7141753
# 1/1 [==============================] - 0s 23ms/step
# Class: surprise
# Confidence Score: 0.68370205
# 1/1 [==============================] - 0s 26ms/step
# Class: surprise
# Confidence Score: 0.81234723
# 1/1 [==============================] - 0s 26ms/step
# Class: surprise
# Confidence Score: 0.89256597
# 1/1 [==============================] - 0s 25ms/step
# Class: surprise
# Confidence Score: 0.5677075
# 1/1 [==============================] - 0s 23ms/step
# Class: surprise
# Confidence Score: 0.8284103
# 1/1 [==============================] - 0s 26ms/step
# Class: surprise
# Confidence Score: 0.63970923
# 1/1 [==============================] - 0s 26ms/step
# Class: surprise
# Confidence Score: 0.77159524
# 1/1 [==============================] - 0s 27ms/step
# Class: surprise
# Confidence Score: 0.8826166
# 1/1 [==============================] - 0s 30ms/step
# Class: surprise
# Confidence Score: 0.72209114
# 1/1 [==============================] - 0s 24ms/step
# Class: surprise
# Confidence Score: 0.7970457
# 1/1 [==============================] - 0s 27ms/step
# Class: surprise
# Confidence Score: 0.64665776
# 1/1 [==============================] - 0s 23ms/step
# Class: surprise
# Confidence Score: 0.65326434
# 1/1 [==============================] - 0s 25ms/step
# Class: surprise
# Confidence Score: 0.7984421
# 1/1 [==============================] - 0s 27ms/step
# Class: surprise
# Confidence Score: 0.69427013
# 1/1 [==============================] - 0s 32ms/step
# Class: neutral
# Confidence Score: 0.6493427
# 1/1 [==============================] - 0s 25ms/step
# Class: surprise
# Confidence Score: 0.71412754
# 1/1 [==============================] - 0s 23ms/step
# Class: surprise
# Confidence Score: 0.77706414
# 1/1 [==============================] - 0s 24ms/step
# Class: surprise
# Confidence Score: 0.7533878
# 1/1 [==============================] - 0s 23ms/step
# Class: surprise
# Confidence Score: 0.7682331
# 1/1 [==============================] - 0s 24ms/step
# Class: surprise
# Confidence Score: 0.6546264
# 1/1 [==============================] - 0s 24ms/step
# Class: surprise
# Confidence Score: 0.70836407
# 1/1 [==============================] - 0s 27ms/step
# Class: neutral
# Confidence Score: 0.5160578
# 1/1 [==============================] - 0s 27ms/step
# Class: surprise
# Confidence Score: 0.7452158
# 1/1 [==============================] - 0s 32ms/step
# Class: surprise
# Confidence Score: 0.8601806
# 1/1 [==============================] - 0s 24ms/step
# Class: surprise
# Confidence Score: 0.5352508
# 1/1 [==============================] - 0s 25ms/step
# Class: surprise
# Confidence Score: 0.80807436
# 1/1 [==============================] - 0s 27ms/step
# Class: surprise
# Confidence Score: 0.9215334
# 1/1 [==============================] - 0s 23ms/step
# Class: surprise
# Confidence Score: 0.7374273
# 1/1 [==============================] - 0s 27ms/step
# Class: happy
# Confidence Score: 0.7292167
# 1/1 [==============================] - 0s 31ms/step
# Class: neutral
# Confidence Score: 0.8013021
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.6030774
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.56690246
# 1/1 [==============================] - 0s 25ms/step
# Class: happy
# Confidence Score: 0.74741524
# 1/1 [==============================] - 0s 24ms/step
# Class: angry
# Confidence Score: 0.78674114
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.9933495
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.99792033
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.99902725
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.99795926
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.9958294
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.9989473
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.99565446
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.9905359
# 1/1 [==============================] - 0s 24ms/step
# Class: angry
# Confidence Score: 0.9718645
# 1/1 [==============================] - 0s 30ms/step
# Class: neutral
# Confidence Score: 0.859068
# 1/1 [==============================] - 0s 24ms/step
# Class: angry
# Confidence Score: 0.9838673
# 1/1 [==============================] - 0s 27ms/step
# Class: angry
# Confidence Score: 0.9572275
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.9686555
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.98377913
# 1/1 [==============================] - 0s 26ms/step
# Class: angry
# Confidence Score: 0.824157
# 1/1 [==============================] - 0s 23ms/step
# Class: angry
# Confidence Score: 0.6340881
# 1/1 [==============================] - 0s 25ms/step
# Class: angry
# Confidence Score: 0.98698795
# 1/1 [==============================] - 0s 24ms/step
# Class: angry
# Confidence Score: 0.92251563
# 1/1 [==============================] - 0s 24ms/step
# Class: angry
# Confidence Score: 0.87035316
# 1/1 [==============================] - 0s 23ms/step
# Class: angry
# Confidence Score: 0.89644045
# 1/1 [==============================] - 0s 26ms/step
# Class: angry
# Confidence Score: 0.98449165
# 1/1 [==============================] - 0s 26ms/step
# Class: angry
# Confidence Score: 0.97733784
# 1/1 [==============================] - 0s 25ms/step
# Class: angry
# Confidence Score: 0.9812181
# 1/1 [==============================] - 0s 24ms/step
# Class: angry
# Confidence Score: 0.9858181
# 1/1 [==============================] - 0s 25ms/step
# Class: angry
# Confidence Score: 0.9263798
# 1/1 [==============================] - 0s 24ms/step
# Class: angry
# Confidence Score: 0.96541214
# 1/1 [==============================] - 0s 23ms/step
# Class: angry
# Confidence Score: 0.9761874
# 1/1 [==============================] - 0s 25ms/step
# Class: angry
# Confidence Score: 0.78995514
# 1/1 [==============================] - 0s 24ms/step
# Class: angry
# Confidence Score: 0.92797357
# 1/1 [==============================] - 0s 28ms/step
# Class: angry
# Confidence Score: 0.99228644
# 1/1 [==============================] - 0s 25ms/step
# Class: angry
# Confidence Score: 0.9164886
# 1/1 [==============================] - 0s 25ms/step
# Class: angry
# Confidence Score: 0.88231826
# 1/1 [==============================] - 0s 25ms/step
# Class: angry
# Confidence Score: 0.98384815
# 1/1 [==============================] - 0s 26ms/step
# Class: angry
# Confidence Score: 0.98577636
# 1/1 [==============================] - 0s 24ms/step
# Class: angry
# Confidence Score: 0.83229285
# 1/1 [==============================] - 0s 34ms/step
# Class: angry
# Confidence Score: 0.97351927
# 1/1 [==============================] - 0s 23ms/step
# Class: angry
# Confidence Score: 0.69425213
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.9935867
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.9989685
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.9974299
# 1/1 [==============================] - 0s 32ms/step
# Class: surprise
# Confidence Score: 0.48710525
# 1/1 [==============================] - 0s 25ms/step
# Class: angry
# Confidence Score: 0.5221047
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.99905103
# 1/1 [==============================] - 0s 24ms/step
# Class: happy
# Confidence Score: 0.9303953
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.9949616
# 1/1 [==============================] - 0s 24ms/step
# Class: sad
# Confidence Score: 0.48028997
# 1/1 [==============================] - 0s 28ms/step
# Class: neutral
# Confidence Score: 0.997251
# 1/1 [==============================] - 0s 25ms/step
# Class: sad
# Confidence Score: 0.41875896
# 1/1 [==============================] - 0s 25ms/step
# Class: angry
# Confidence Score: 0.66114455
# 1/1 [==============================] - 0s 24ms/step
# Class: angry
# Confidence Score: 0.64681554
# 1/1 [==============================] - 0s 24ms/step
# Class: angry
# Confidence Score: 0.5457146
# 1/1 [==============================] - 0s 23ms/step
# Class: angry
# Confidence Score: 0.5808962
# 1/1 [==============================] - 0s 33ms/step
# Class: angry
# Confidence Score: 0.8356228
# 1/1 [==============================] - 0s 24ms/step
# Class: surprise
# Confidence Score: 0.45438462
# 1/1 [==============================] - 0s 24ms/step
# Class: sad
# Confidence Score: 0.48913532
# 1/1 [==============================] - 0s 24ms/step
# Class: angry
# Confidence Score: 0.4217591
# 1/1 [==============================] - 0s 25ms/step
# Class: surprise
# Confidence Score: 0.5064292
# 1/1 [==============================] - 0s 28ms/step
# Class: angry
# Confidence Score: 0.9994797
# 1/1 [==============================] - 0s 33ms/step
# Class: surprise
# Confidence Score: 0.4545793
# 1/1 [==============================] - 0s 22ms/step
# Class: angry
# Confidence Score: 0.42813823
# 1/1 [==============================] - 0s 25ms/step
# Class: angry
# Confidence Score: 0.53429085
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.61867195
# 1/1 [==============================] - 0s 24ms/step
# Class: sad
# Confidence Score: 0.42229545
# 1/1 [==============================] - 0s 25ms/step
# Class: sad
# Confidence Score: 0.6255588
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.49645287
# 1/1 [==============================] - 0s 27ms/step
# Class: angry
# Confidence Score: 0.99992263
# 1/1 [==============================] - 0s 25ms/step
# Class: sad
# Confidence Score: 0.53330624
# 1/1 [==============================] - 0s 24ms/step
# Class: sad
# Confidence Score: 0.4500475
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.44322407
# 1/1 [==============================] - 0s 24ms/step
# Class: sad
# Confidence Score: 0.63837487
# 1/1 [==============================] - 0s 26ms/step
# Class: sad
# Confidence Score: 0.47724718
# 1/1 [==============================] - 0s 28ms/step
# Class: sad
# Confidence Score: 0.67148465
# 1/1 [==============================] - 0s 24ms/step
# Class: sad
# Confidence Score: 0.47643378
# 1/1 [==============================] - 0s 25ms/step
# Class: sad
# Confidence Score: 0.65380335
# 1/1 [==============================] - 0s 27ms/step
# Class: neutral
# Confidence Score: 0.9800157
# 1/1 [==============================] - 0s 28ms/step
# Class: angry
# Confidence Score: 0.9999808
# 1/1 [==============================] - 0s 23ms/step
# Class: sad
# Confidence Score: 0.5533692
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.51933247
# 1/1 [==============================] - 0s 24ms/step
# Class: angry
# Confidence Score: 0.9995059
# 1/1 [==============================] - 0s 23ms/step
# Class: sad
# Confidence Score: 0.44749647
# 1/1 [==============================] - 0s 27ms/step
# Class: sad
# Confidence Score: 0.7185393
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.41341567
# 1/1 [==============================] - 0s 24ms/step
# Class: sad
# Confidence Score: 0.7903702
# 1/1 [==============================] - 0s 28ms/step
# Class: surprise
# Confidence Score: 0.38804182
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.46548295
# 1/1 [==============================] - 0s 25ms/step
# Class: sad
# Confidence Score: 0.41923085
# 1/1 [==============================] - 0s 24ms/step
# Class: sad
# Confidence Score: 0.7864428
# 1/1 [==============================] - 0s 32ms/step
# Class: neutral
# Confidence Score: 0.36694878
# 1/1 [==============================] - 0s 24ms/step
# Class: sad
# Confidence Score: 0.55112845
# 1/1 [==============================] - 0s 33ms/step
# Class: sad
# Confidence Score: 0.74447405
# 1/1 [==============================] - 0s 23ms/step
# Class: sad
# Confidence Score: 0.3372481
# 1/1 [==============================] - 0s 24ms/step
# Class: sad
# Confidence Score: 0.43555582
# 1/1 [==============================] - 0s 24ms/step
# Class: sad
# Confidence Score: 0.8062462
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.6310483
# 1/1 [==============================] - 0s 24ms/step
# Class: angry
# Confidence Score: 0.99512
# 1/1 [==============================] - 0s 28ms/step
# Class: sad
# Confidence Score: 0.6642008
# 1/1 [==============================] - 0s 28ms/step
# Class: sad
# Confidence Score: 0.5338027
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.36091802
# 1/1 [==============================] - 0s 33ms/step
# Class: sad
# Confidence Score: 0.6182115
# 1/1 [==============================] - 0s 23ms/step
# Class: sad
# Confidence Score: 0.635958
# 1/1 [==============================] - 0s 31ms/step
# Class: sad
# Confidence Score: 0.52981806
# 1/1 [==============================] - 0s 34ms/step
# Class: sad
# Confidence Score: 0.4115311
# 1/1 [==============================] - 0s 23ms/step
# Class: sad
# Confidence Score: 0.4539769
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.9869228
# 1/1 [==============================] - 0s 25ms/step
# Class: angry
# Confidence Score: 0.99949527
# 1/1 [==============================] - 0s 24ms/step
# Class: sad
# Confidence Score: 0.37439403
# 1/1 [==============================] - 0s 24ms/step
# Class: angry
# Confidence Score: 0.43428522
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.98299605
# 1/1 [==============================] - 0s 29ms/step
# Class: neutral
# Confidence Score: 0.85533935
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.906855
# 1/1 [==============================] - 0s 29ms/step
# Class: sad
# Confidence Score: 0.79195654
# 1/1 [==============================] - 0s 28ms/step
# Class: sad
# Confidence Score: 0.7624909
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.8942216
# 1/1 [==============================] - 0s 29ms/step
# Class: angry
# Confidence Score: 0.9986607
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.81894225
# 1/1 [==============================] - 0s 26ms/step
# Class: angry
# Confidence Score: 0.9999956
# 1/1 [==============================] - 0s 23ms/step
# Class: sad
# Confidence Score: 0.63470376
# 1/1 [==============================] - 0s 23ms/step
# Class: sad
# Confidence Score: 0.8081585
# 1/1 [==============================] - 0s 24ms/step
# Class: sad
# Confidence Score: 0.7556144
# 1/1 [==============================] - 0s 33ms/step
# Class: neutral
# Confidence Score: 0.5553253
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.55130714
# 1/1 [==============================] - 0s 23ms/step
# Class: sad
# Confidence Score: 0.89142007
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.63007647
# 1/1 [==============================] - 0s 24ms/step
# Class: sad
# Confidence Score: 0.49602804
# 1/1 [==============================] - 0s 23ms/step
# Class: sad
# Confidence Score: 0.7556417
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.5293479
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.41620758
# 1/1 [==============================] - 0s 27ms/step
# Class: neutral
# Confidence Score: 0.62013894
# 1/1 [==============================] - 0s 25ms/step
# Class: sad
# Confidence Score: 0.4541911
# 1/1 [==============================] - 0s 32ms/step
# Class: sad
# Confidence Score: 0.89640796
# 1/1 [==============================] - 0s 25ms/step
# Class: sad
# Confidence Score: 0.5863966
# 1/1 [==============================] - 0s 28ms/step
# Class: sad
# Confidence Score: 0.8193021
# 1/1 [==============================] - 0s 31ms/step
# Class: sad
# Confidence Score: 0.5916831
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.41809243
# 1/1 [==============================] - 0s 23ms/step
# Class: sad
# Confidence Score: 0.7829708
# 1/1 [==============================] - 0s 23ms/step
# Class: sad
# Confidence Score: 0.8963293
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.9915072
# 1/1 [==============================] - 0s 32ms/step
# Class: angry
# Confidence Score: 0.9997813
# 1/1 [==============================] - 0s 25ms/step
# Class: sad
# Confidence Score: 0.68215215
# 1/1 [==============================] - 0s 24ms/step
# Class: sad
# Confidence Score: 0.945739
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.6806188
# 1/1 [==============================] - 0s 23ms/step
# Class: angry
# Confidence Score: 0.3633033
# 1/1 [==============================] - 0s 26ms/step
# Class: sad
# Confidence Score: 0.8211488
# 1/1 [==============================] - 0s 28ms/step
# Class: sad
# Confidence Score: 0.5593797
# 1/1 [==============================] - 0s 23ms/step
# Class: sad
# Confidence Score: 0.85522693
# 1/1 [==============================] - 0s 26ms/step
# Class: sad
# Confidence Score: 0.5338224
# 1/1 [==============================] - 0s 28ms/step
# Class: sad
# Confidence Score: 0.5243102
# 1/1 [==============================] - 0s 23ms/step
# Class: sad
# Confidence Score: 0.8642858
# 1/1 [==============================] - 0s 24ms/step
# Class: sad
# Confidence Score: 0.5141905
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.44294003
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.46849498
# 1/1 [==============================] - 0s 23ms/step
# Class: sad
# Confidence Score: 0.4332142
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.5975233
# 1/1 [==============================] - 0s 23ms/step
# Class: angry
# Confidence Score: 0.67085916
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.9989188
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.99496526
# 1/1 [==============================] - 0s 26ms/step
# Class: happy
# Confidence Score: 0.9516079
# 1/1 [==============================] - 0s 23ms/step
# Class: angry
# Confidence Score: 0.530096
# 1/1 [==============================] - 0s 24ms/step
# Class: happy
# Confidence Score: 0.6263346
# 1/1 [==============================] - 0s 29ms/step
# Class: surprise
# Confidence Score: 0.72694707
# 1/1 [==============================] - 0s 29ms/step
# Class: happy
# Confidence Score: 0.81093353
# 1/1 [==============================] - 0s 24ms/step
# Class: angry
# Confidence Score: 0.7757175
# 1/1 [==============================] - 0s 24ms/step
# Class: angry
# Confidence Score: 0.89583766
# 1/1 [==============================] - 0s 24ms/step
# Class: angry
# Confidence Score: 0.8809874
# 1/1 [==============================] - 0s 28ms/step
# Class: angry
# Confidence Score: 0.86874574
# 1/1 [==============================] - 0s 30ms/step
# Class: neutral
# Confidence Score: 0.9927979
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.9035648
# 1/1 [==============================] - 0s 23ms/step
# Class: happy
# Confidence Score: 0.51297086
# 1/1 [==============================] - 0s 23ms/step
# Class: angry
# Confidence Score: 0.6173905
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.95521355
# 1/1 [==============================] - 0s 22ms/step
# Class: sad
# Confidence Score: 0.6453444
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.6391359
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.7796654
# 1/1 [==============================] - 0s 30ms/step
# Class: surprise
# Confidence Score: 0.4532995
# 1/1 [==============================] - 0s 25ms/step
# Class: surprise
# Confidence Score: 0.4696301
# 1/1 [==============================] - 0s 25ms/step
# Class: surprise
# Confidence Score: 0.6889254
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.6014317
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.6048467
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.5952446
# 1/1 [==============================] - 0s 27ms/step
# Class: neutral
# Confidence Score: 0.57377225
# 1/1 [==============================] - 0s 24ms/step
# Class: surprise
# Confidence Score: 0.50495017
# 1/1 [==============================] - 0s 25ms/step
# Class: surprise
# Confidence Score: 0.92613834
# 1/1 [==============================] - 0s 23ms/step
# Class: surprise
# Confidence Score: 0.7018373
# 1/1 [==============================] - 0s 25ms/step
# Class: surprise
# Confidence Score: 0.7372998
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.49738106
# 1/1 [==============================] - 0s 23ms/step
# Class: surprise
# Confidence Score: 0.45999077
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.48233548
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.5754678
# 1/1 [==============================] - 0s 30ms/step
# Class: surprise
# Confidence Score: 0.48777607
# 1/1 [==============================] - 0s 23ms/step
# Class: surprise
# Confidence Score: 0.68703127
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.38128886
# 1/1 [==============================] - 0s 33ms/step
# Class: surprise
# Confidence Score: 0.61066747
# 1/1 [==============================] - 0s 25ms/step
# Class: surprise
# Confidence Score: 0.79035735
# 1/1 [==============================] - 0s 24ms/step
# Class: surprise
# Confidence Score: 0.4659802
# 1/1 [==============================] - 0s 24ms/step
# Class: surprise
# Confidence Score: 0.6649557
# 1/1 [==============================] - 0s 24ms/step
# Class: surprise
# Confidence Score: 0.43990576
# 1/1 [==============================] - 0s 23ms/step
# Class: surprise
# Confidence Score: 0.53034294
# 1/1 [==============================] - 0s 23ms/step
# Class: surprise
# Confidence Score: 0.55438733
# 1/1 [==============================] - 0s 25ms/step
# Class: surprise
# Confidence Score: 0.64365333
# 1/1 [==============================] - 0s 27ms/step
# Class: neutral
# Confidence Score: 0.6022809
# 1/1 [==============================] - 0s 23ms/step
# Class: surprise
# Confidence Score: 0.764788
# 1/1 [==============================] - 0s 27ms/step
# Class: neutral
# Confidence Score: 0.73988533
# 1/1 [==============================] - 0s 28ms/step
# Class: neutral
# Confidence Score: 0.9964567
# 1/1 [==============================] - 0s 28ms/step
# Class: neutral
# Confidence Score: 0.9951237
# 1/1 [==============================] - 0s 23ms/step
# Class: happy
# Confidence Score: 0.9872694
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.9052677
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.99752444
# 1/1 [==============================] - 0s 23ms/step
# Class: happy
# Confidence Score: 0.8577277
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.72046125
# 1/1 [==============================] - 0s 27ms/step
# Class: neutral
# Confidence Score: 0.9912435
# 1/1 [==============================] - 0s 32ms/step
# Class: angry
# Confidence Score: 0.573493
# 1/1 [==============================] - 0s 25ms/step
# Class: angry
# Confidence Score: 0.9489213
# 1/1 [==============================] - 0s 25ms/step
# Class: angry
# Confidence Score: 0.9962663
# 1/1 [==============================] - 0s 28ms/step
# ...
# 1/1 [==============================] - 0s 28ms/step
# Class: happy
# Confidence Score: 0.56094205
# 1/1 [==============================] - 0s 35ms/step
# Class: neutral
# Confidence Score: 0.71507984
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.7712119
# 1/1 [==============================] - 0s 28ms/step
# Class: happy
# Confidence Score: 0.51963025
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.6893489
# 1/1 [==============================] - 0s 27ms/step
# Class: happy
# Confidence Score: 0.38920137
# 1/1 [==============================] - 0s 29ms/step
# Class: neutral
# Confidence Score: 0.6780768
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.4808663
# 1/1 [==============================] - 0s 41ms/step
# Class: neutral
# Confidence Score: 0.49937737
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.50168425
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.6317444
# 1/1 [==============================] - 0s 27ms/step
# Class: happy
# Confidence Score: 0.41864827
# 1/1 [==============================] - 0s 35ms/step
# Class: neutral
# Confidence Score: 0.802991
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.7605088
# 1/1 [==============================] - 0s 27ms/step
# Class: happy
# Confidence Score: 0.8254962
# 1/1 [==============================] - 0s 29ms/step
# Class: happy
# Confidence Score: 0.63606435
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.5313549
# 1/1 [==============================] - 0s 24ms/step
# Class: happy
# Confidence Score: 0.44920915
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.8359435
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.6008868
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.39143443
# 1/1 [==============================] - 0s 24ms/step
# Class: happy
# Confidence Score: 0.5025769
# 1/1 [==============================] - 0s 27ms/step
# Class: neutral
# Confidence Score: 0.47887087
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.40577552
# 1/1 [==============================] - 0s 25ms/step
# Class: surprise
# Confidence Score: 0.3952835
# 1/1 [==============================] - 0s 25ms/step
# Class: happy
# Confidence Score: 0.6939589
# 1/1 [==============================] - 0s 28ms/step
# Class: neutral
# Confidence Score: 0.59595895
# 1/1 [==============================] - 0s 24ms/step
# Class: sad
# Confidence Score: 0.35852608
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.6062211
# 1/1 [==============================] - 0s 28ms/step
# Class: neutral
# Confidence Score: 0.83625937
# 1/1 [==============================] - 0s 26ms/step
# Class: happy
# Confidence Score: 0.8947246
# 1/1 [==============================] - 0s 26ms/step
# Class: surprise
# Confidence Score: 0.9144137
# 1/1 [==============================] - 0s 31ms/step
# Class: happy
# Confidence Score: 0.7205605
# 1/1 [==============================] - 0s 30ms/step
# Class: surprise
# Confidence Score: 0.6485523
# 1/1 [==============================] - 0s 28ms/step
# Class: surprise
# Confidence Score: 0.9377063
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.7566115
# 1/1 [==============================] - 0s 24ms/step
# Class: happy
# Confidence Score: 0.92353654
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.5912191
# 1/1 [==============================] - 0s 25ms/step
# Class: happy
# Confidence Score: 0.94084764
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.729093
# 1/1 [==============================] - 0s 23ms/step
# Class: happy
# Confidence Score: 0.531566
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.82845277
# 1/1 [==============================] - 0s 33ms/step
# Class: neutral
# Confidence Score: 0.99948466
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.9995653
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.99929285
# 1/1 [==============================] - 0s 27ms/step
# Class: neutral
# Confidence Score: 0.99877006
# 1/1 [==============================] - 0s 29ms/step
# Class: happy
# Confidence Score: 0.92161703
# 1/1 [==============================] - 0s 25ms/step
# Class: surprise
# Confidence Score: 0.44516507
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.97959137
# 1/1 [==============================] - 0s 24ms/step
# Class: happy
# Confidence Score: 0.8271832
# 1/1 [==============================] - 0s 37ms/step
# Class: neutral
# Confidence Score: 0.58252573
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.8798826
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.98904324
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.98054296
# 1/1 [==============================] - 0s 34ms/step
# Class: neutral
# Confidence Score: 0.9910856
# 1/1 [==============================] - 0s 27ms/step
# Class: sad
# Confidence Score: 0.6580829
# 1/1 [==============================] - 0s 25ms/step
# Class: happy
# Confidence Score: 0.80817986
# 1/1 [==============================] - 0s 27ms/step
# Class: surprise
# Confidence Score: 0.5231594
# 1/1 [==============================] - 0s 44ms/step
# Class: sad
# Confidence Score: 0.9808499
# 1/1 [==============================] - 0s 28ms/step
# Class: neutral
# Confidence Score: 0.971974
# 1/1 [==============================] - 0s 27ms/step
# Class: sad
# Confidence Score: 0.8706518
# 1/1 [==============================] - 0s 27ms/step
# Class: neutral
# Confidence Score: 0.7940071
# 1/1 [==============================] - 0s 24ms/step
# Class: surprise
# Confidence Score: 0.55288196
# 1/1 [==============================] - 0s 33ms/step
# Class: neutral
# Confidence Score: 0.77062935
# 1/1 [==============================] - 0s 23ms/step
# Class: surprise
# Confidence Score: 0.599639
# 1/1 [==============================] - 0s 29ms/step
# Class: neutral
# Confidence Score: 0.99679524
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.537648
# 1/1 [==============================] - 0s 32ms/step
# Class: neutral
# Confidence Score: 0.9762841
# 1/1 [==============================] - 0s 26ms/step
# Class: sad
# Confidence Score: 0.85538286
# 1/1 [==============================] - 0s 28ms/step
# Class: neutral
# Confidence Score: 0.978563
# 1/1 [==============================] - 0s 29ms/step
# Class: sad
# Confidence Score: 0.4960837
# 1/1 [==============================] - 0s 27ms/step
# Class: neutral
# Confidence Score: 0.65198225
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.6193158
# 1/1 [==============================] - 0s 27ms/step
# Class: sad
# Confidence Score: 0.66595125
# 1/1 [==============================] - 0s 25ms/step
# Class: sad
# Confidence Score: 0.7054524
# 1/1 [==============================] - 0s 24ms/step
# Class: sad
# Confidence Score: 0.60806024
# 1/1 [==============================] - 0s 23ms/step
# Class: sad
# Confidence Score: 0.87156886
# 1/1 [==============================] - 0s 26ms/step
# Class: sad
# Confidence Score: 0.9407302
# 1/1 [==============================] - 0s 30ms/step
# Class: sad
# Confidence Score: 0.8729209
# 1/1 [==============================] - 0s 23ms/step
# Class: sad
# Confidence Score: 0.91128933
# 1/1 [==============================] - 0s 27ms/step
# Class: sad
# Confidence Score: 0.73233265
# 1/1 [==============================] - 0s 27ms/step
# Class: sad
# Confidence Score: 0.62460613
# 1/1 [==============================] - 0s 35ms/step
# Class: neutral
# Confidence Score: 0.6978488
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.74797267
# 1/1 [==============================] - 0s 25ms/step
# Class: sad
# Confidence Score: 0.586422
# 1/1 [==============================] - 0s 26ms/step
# Class: sad
# Confidence Score: 0.6179307
# 1/1 [==============================] - 0s 25ms/step
# Class: sad
# Confidence Score: 0.43773103
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.43668592
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.53864336
# 1/1 [==============================] - 0s 25ms/step
# Class: sad
# Confidence Score: 0.700922
# 1/1 [==============================] - 0s 26ms/step
# Class: sad
# Confidence Score: 0.47032428
# 1/1 [==============================] - 0s 31ms/step
# Class: sad
# Confidence Score: 0.83722335
# 1/1 [==============================] - 0s 26ms/step
# Class: sad
# Confidence Score: 0.68208534
# 1/1 [==============================] - 0s 26ms/step
# Class: sad
# Confidence Score: 0.5494426
# 1/1 [==============================] - 0s 27ms/step
# Class: neutral
# Confidence Score: 0.41545758
# 1/1 [==============================] - 0s 25ms/step
# Class: sad
# Confidence Score: 0.8348696
# 1/1 [==============================] - 0s 26ms/step
# Class: sad
# Confidence Score: 0.9364824
# 1/1 [==============================] - 0s 28ms/step
# Class: neutral
# Confidence Score: 0.9378197
# 1/1 [==============================] - 0s 30ms/step
# Class: neutral
# Confidence Score: 0.8802897
# 1/1 [==============================] - 0s 30ms/step
# Class: surprise
# Confidence Score: 0.51295024
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.996384
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.88966656
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.9955331
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.98225075
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.9970618
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.9994425
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.9841474
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.9969994
# 1/1 [==============================] - 0s 28ms/step
# Class: happy
# Confidence Score: 0.7849935
# 1/1 [==============================] - 0s 28ms/step
# Class: neutral
# Confidence Score: 0.45230258
# 1/1 [==============================] - 0s 30ms/step
# Class: neutral
# Confidence Score: 0.9769719
# 1/1 [==============================] - 0s 26ms/step
# Class: happy
# Confidence Score: 0.8334459
# 1/1 [==============================] - 0s 29ms/step
# Class: neutral
# Confidence Score: 0.7744819
# 1/1 [==============================] - 0s 31ms/step
# Class: neutral
# Confidence Score: 0.9958198
# 1/1 [==============================] - 0s 27ms/step
# Class: neutral
# Confidence Score: 0.99797696
# 1/1 [==============================] - 0s 25ms/step
# Class: happy
# Confidence Score: 0.9587754
# 1/1 [==============================] - 0s 33ms/step
# Class: neutral
# Confidence Score: 0.73866266
# 1/1 [==============================] - 0s 25ms/step
# Class: surprise
# Confidence Score: 0.60067993
# 1/1 [==============================] - 0s 30ms/step
# Class: neutral
# Confidence Score: 0.6821626
# 1/1 [==============================] - 0s 30ms/step
# Class: neutral
# Confidence Score: 0.99244267
# 1/1 [==============================] - 0s 27ms/step
# Class: neutral
# Confidence Score: 0.9927026
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.9829117
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.9987458
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.99920446
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.9995888
# 1/1 [==============================] - 0s 26ms/step
# Class: happy
# Confidence Score: 0.82288533
# 1/1 [==============================] - 0s 32ms/step
# Class: surprise
# Confidence Score: 0.5339577
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.9938783
# 1/1 [==============================] - 0s 27ms/step
# Class: happy
# Confidence Score: 0.80101216
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.60893387
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.9694606
# 1/1 [==============================] - 0s 26ms/step
# Class: happy
# Confidence Score: 0.92527753
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.48882702
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.98059523
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.9721933
# 1/1 [==============================] - 0s 28ms/step
# Class: happy
# Confidence Score: 0.740471
# 1/1 [==============================] - 0s 24ms/step
# Class: surprise
# Confidence Score: 0.54178804
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.92353845
# 1/1 [==============================] - 0s 24ms/step
# Class: happy
# Confidence Score: 0.72539276
# 1/1 [==============================] - 0s 25ms/step
# Class: angry
# Confidence Score: 0.42202678
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.935205
# 1/1 [==============================] - 0s 38ms/step
# Class: neutral
# Confidence Score: 0.95985985
# 1/1 [==============================] - 0s 30ms/step
# Class: neutral
# Confidence Score: 0.9877417
# 1/1 [==============================] - 0s 29ms/step
# Class: neutral
# Confidence Score: 0.9982845
# 1/1 [==============================] - 0s 26ms/step
# Class: happy
# Confidence Score: 0.97744274
# 1/1 [==============================] - 0s 33ms/step
# Class: neutral
# Confidence Score: 0.48622316
# 1/1 [==============================] - 0s 29ms/step
# Class: neutral
# Confidence Score: 0.98762053
# 1/1 [==============================] - 0s 29ms/step
# Class: neutral
# Confidence Score: 0.97667706
# 1/1 [==============================] - 0s 31ms/step
# Class: neutral
# Confidence Score: 0.9911875
# 1/1 [==============================] - 0s 29ms/step
# Class: neutral
# Confidence Score: 0.9423983
# 1/1 [==============================] - 0s 28ms/step
# Class: neutral
# Confidence Score: 0.98500985
# 1/1 [==============================] - 0s 28ms/step
# Class: neutral
# Confidence Score: 0.9813037
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.95211434
# 1/1 [==============================] - 0s 22ms/step
# Class: neutral
# Confidence Score: 0.9947596
# 1/1 [==============================] - 0s 28ms/step
# Class: neutral
# Confidence Score: 0.94285464
# 1/1 [==============================] - 0s 28ms/step
# Class: neutral
# Confidence Score: 0.9624599
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.988315
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.9933161
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.9947817
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.9871633
# 1/1 [==============================] - 0s 29ms/step
# Class: neutral
# Confidence Score: 0.97467947
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.9933689
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.97520304
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.98723185
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.9963768
# 1/1 [==============================] - 0s 25ms/step
# Class: neutral
# Confidence Score: 0.98966867
# 1/1 [==============================] - 0s 23ms/step
# Class: neutral
# Confidence Score: 0.992679
# 1/1 [==============================] - 0s 26ms/step
# Class: neutral
# Confidence Score: 0.9980355
# 1/1 [==============================] - 0s 24ms/step
# Class: neutral
# Confidence Score: 0.9974699
