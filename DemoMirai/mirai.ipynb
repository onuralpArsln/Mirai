# %% [markdown]
# # Demo Version

# %%
#  General Prep  Made Here

import cv2
import time

from keras.models import load_model  # TensorFlow is required for Keras to work
from PIL import Image, ImageOps  # Install pillow instead of PIL
import numpy as np
# pip install tensorflow==2.12.1 

import statistics

# Disable scientific notation for clarity
np.set_printoptions(suppress=True)
# Load the model
model = load_model("keras_model.h5", compile=False)
# Load the labels
class_names = open("labels.txt", "r").readlines()

# Create the array of the right shape to feed into the keras model
# The 'length' or number of images you can put into the array is
# determined by the first position in the shape tuple, in this case 1
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)


# Load the pre-trained Haar Cascade for face detection
cascade_path = 'haarcascade_frontalface_default.xml'
face_cascade = cv2.CascadeClassifier(cascade_path)

# Check if the cascade file is loaded correctly
if face_cascade.empty():
    raise IOError(f"Failed to load cascade classifier from {cascade_path}")

# Create a video capture object
cap = cv2.VideoCapture(0)  # 0 for the default camera

# Check if the webcam is opened correctly
if not cap.isOpened():
    raise ValueError("Unable to open video source")

# Define fixed window size for cropped face display
fixed_window_size = (224, 224)  # Width, Height

# Desired frame rate
desired_fps = 10
frame_duration = 1 / desired_fps  # Duration of each frame in seconds

# Define text parameters
text_size = 0.8  # Change this value to increase or decrease text size
text_color = (0, 255, 0)  # Text color in BGR format (Green)
text_thickness = 2  # Thickness of the text stroke
shadow_color = (0, 0, 0)  # Shadow color in BGR format (Black)
shadow_offset = (0, 0)  # Offset for shadow position

lastGuess=[]
text="text here"
guess="calculating"



try:
    while True:
        start_time = time.time()  # Start time of the loop

        # Capture frame-by-frame
        ret, frame = cap.read()  # ret is a boolean, frame is the captured image

        if not ret:  # Check if the frame was captured successfully
            print("Failed to capture image")
            break

        # Convert frame to grayscale for face detection
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        # Detect faces in the frame
        faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

        # Draw a rectangle around each face and crop the face
        for (x, y, w, h) in faces:
            cv2.rectangle(frame, (x, y), (x + w, y + h), (255, 0, 0), 2)
            
            # Crop the face region
            face_crop = frame[y:y + h, x:x + w]

            # Resize the cropped face to the fixed window size
            face_crop_resized = cv2.resize(face_crop, fixed_window_size)

            # Add shadow text to the cropped face window
         
            font = cv2.FONT_HERSHEY_SIMPLEX
            # Calculate text size for shadow
            (text_width, text_height), baseline = cv2.getTextSize(text, font, text_size, text_thickness)
            text_x, text_y = 10, 30  # Position for the text
            shadow_x, shadow_y = text_x + shadow_offset[0], text_y + shadow_offset[1]

            ##########  
            # Replace this with the path to your image
            file_path="img.jpg"
            cv2.imwrite(file_path, face_crop_resized)
            image = Image.open(file_path).convert("RGB")

            # resizing the image to be at least 224x224 and then cropping from the center
            size = (224, 224)
            image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)

            # turn the image into a numpy array
            image_array = np.asarray(image)

            # Normalize the image
            normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1

            # Load the image into the array
            data[0] = normalized_image_array

            # Predicts the model
            prediction = model.predict(data)
            index = np.argmax(prediction)
            class_name = class_names[index]
            confidence_score = prediction[0][index]

            # Print prediction and confidence score
            print("Class:", class_name[2:], end="")
            print("Confidence Score:", confidence_score)
            

            #guess=f"{class_name[2:]}:{confidence_score}"

            ### make guess not change every frame
            if confidence_score>0.6:
                # add last guesses index
                lastGuess.append(index)
            
                # eğer son 10 tahminden fazla ise ilk indexi pırtlat
                if len(lastGuess)>9:
                    lastGuess.pop(0)
              
                resultIndex=int(statistics.median(lastGuess))
                print(resultIndex)
                class_name = class_names[resultIndex]
                guess=f"{class_name[2:]}:{confidence_score}"

        

            ##########
            # Show Result

            # Draw the shadow (background rectangle)
            cv2.rectangle(face_crop_resized, (shadow_x, shadow_y - text_height), (shadow_x + text_width, shadow_y + baseline), shadow_color, thickness=cv2.FILLED)
            # Draw the text
            cv2.putText(face_crop_resized, guess, (text_x, text_y), font, text_size, text_color, text_thickness, cv2.LINE_AA)

            # Display the cropped face in a separate window
            cv2.imshow('Cropped Face', face_crop_resized)
            # Ensure the window size is fixed
            cv2.resizeWindow('Cropped Face', fixed_window_size[0], fixed_window_size[1])

        # Add shadow text to the main video window
        main_text = 'Press "q" to exit'
        second_text = 'Second Line'
        (text_width, text_height), baseline = cv2.getTextSize(main_text, font, text_size, text_thickness)
        text_x, text_y = 10, 30  # Position for the text
        shadow_x, shadow_y = text_x + shadow_offset[0], text_y + shadow_offset[1]

        # Draw the shadow (background rectangle)
        cv2.rectangle(frame, (shadow_x, shadow_y - text_height), (shadow_x + text_width, shadow_y*2 + baseline), shadow_color, thickness=cv2.FILLED)
        # Draw the text
        cv2.putText(frame, main_text, (text_x, text_y), font, text_size, text_color, text_thickness, cv2.LINE_AA)
        
        # second text
        cv2.putText(frame, second_text, (text_x, text_y*2), font, text_size, text_color, text_thickness, cv2.LINE_AA)

        # Display the resulting frame in a window named 'Video'
        cv2.imshow('Video', frame)

        # Calculate the time taken for one loop iteration
        elapsed_time = time.time() - start_time
        # Calculate the delay needed to maintain the desired frame rate
        delay = max(1, int((frame_duration - elapsed_time) * 1000))
        
        # Break the loop if 'q' key is pressed
        if cv2.waitKey(delay) & 0xFF == ord('q'):
            break

except KeyboardInterrupt:
    pass
finally:
    # Release the capture and close windows
    cap.release()
    cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 1s 690ms/step
# Class: focused
# Confidence Score: 0.9847476
# 0
# 1/1 [==============================] - 0s 25ms/step
# Class: focused
# Confidence Score: 0.8365187
# 0
# 1/1 [==============================] - 0s 26ms/step
# Class: focused
# Confidence Score: 0.96351784
# 0
# 1/1 [==============================] - 0s 25ms/step
# Class: focused
# Confidence Score: 0.9347937
# 0
# 1/1 [==============================] - 0s 24ms/step
# Class: focused
# Confidence Score: 0.9852579
# 0
# 1/1 [==============================] - 0s 24ms/step
# Class: focused
# Confidence Score: 0.94140565
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.8266407
# 0
# 1/1 [==============================] - 0s 24ms/step
# Class: focused
# Confidence Score: 0.96705765
# 0
# 1/1 [==============================] - 0s 25ms/step
# Class: focused
# Confidence Score: 0.9625024
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.9543104
# 0
# 1/1 [==============================] - 0s 24ms/step
# Class: focused
# Confidence Score: 0.90308136
# 0
# 1/1 [==============================] - 0s 25ms/step
# Class: focused
# Confidence Score: 0.93614364
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.9133491
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.91298574
# 0
# 1/1 [==============================] - 0s 25ms/step
# Class: focused
# Confidence Score: 0.96989733
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.7833969
# 0
# 1/1 [==============================] - 0s 25ms/step
# Class: focused
# Confidence Score: 0.95966554
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.9659167
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.9442133
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.9250493
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.90545416
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.95339304
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.97691524
# 0
# 1/1 [==============================] - 0s 24ms/step
# Class: focused
# Confidence Score: 0.9603224
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.9603224
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.9938141
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.91474175
# 0
# 1/1 [==============================] - 0s 24ms/step
# Class: focused
# Confidence Score: 0.87443084
# 0
# 1/1 [==============================] - 0s 24ms/step
# Class: focused
# Confidence Score: 0.85060096
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.835493
# 0
# 1/1 [==============================] - 0s 24ms/step
# Class: focused
# Confidence Score: 0.64001656
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.7674797
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.5601246
# 1/1 [==============================] - 0s 24ms/step
# Class: confused
# Confidence Score: 0.7194568
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.81318355
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.8742818
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.74499923
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.68292654
# 0
# 1/1 [==============================] - 0s 24ms/step
# Class: focused
# Confidence Score: 0.44733587
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.9746629
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.9634163
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.9736657
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.9472584
# 1
# 1/1 [==============================] - 0s 24ms/step
# Class: confused
# Confidence Score: 0.977417
# 1
# 1/1 [==============================] - 0s 24ms/step
# Class: confused
# Confidence Score: 0.8584951
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.94174707
# 1
# 1/1 [==============================] - 0s 24ms/step
# Class: confused
# Confidence Score: 0.9854671
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.6400259
# 1
# 1/1 [==============================] - 0s 24ms/step
# Class: confused
# Confidence Score: 0.95753217
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.9868802
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.9829873
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.651597
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.8584948
# 1
# 1/1 [==============================] - 0s 24ms/step
# Class: confused
# Confidence Score: 0.8978868
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.8146672
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.98879355
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.9864048
# 1
# 1/1 [==============================] - 0s 25ms/step
# Class: confused
# Confidence Score: 0.9461237
# 1
# 1/1 [==============================] - 0s 21ms/step
# Class: confused
# Confidence Score: 0.98385656
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.96476305
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.8536349
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.9558958
# 1
# 1/1 [==============================] - 0s 21ms/step
# Class: confused
# Confidence Score: 0.99019086
# 1
# 1/1 [==============================] - 0s 24ms/step
# Class: confused
# Confidence Score: 0.9990544
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.96617913
# 1
# 1/1 [==============================] - 0s 24ms/step
# Class: confused
# Confidence Score: 0.96617913
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.55554456
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.8908325
# 1
# 1/1 [==============================] - 0s 21ms/step
# Class: focused
# Confidence Score: 0.5018776
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.73555183
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.73794425
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.8197597
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.89735794
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.8685161
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.6690717
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.53046757
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.87387514
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.7848169
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: distracted
# Confidence Score: 0.6599482
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.6620393
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.72552663
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.81882554
# 0
# 1/1 [==============================] - 0s 24ms/step
# Class: focused
# Confidence Score: 0.93866545
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.9451939
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.9614358
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.9460684
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.81701714
# 0
# 1/1 [==============================] - 0s 21ms/step
# Class: focused
# Confidence Score: 0.9725625
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.79181856
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.7407958
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.90435356
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.877824
# 0
# 1/1 [==============================] - 0s 21ms/step
# Class: focused
# Confidence Score: 0.92130053
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.85203785
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.6431887
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.94088376
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.60644656
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.8356527
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.51820475
# 1/1 [==============================] - 0s 24ms/step
# Class: confused
# Confidence Score: 0.7316018
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.89959854
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.8113172
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.9348519
# 1
# 1/1 [==============================] - 0s 24ms/step
# Class: confused
# Confidence Score: 0.8893736
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.90627193
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.88132334
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.88132334
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.8121453
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.9733496
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.8154689
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.600085
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.76106715
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.93153775
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.9607302
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.8128536
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.76317257
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.5402123
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.92788833
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.72183955
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.7550062
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.58956367
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.88669205
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.88578314
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.7920271
# 0
# 1/1 [==============================] - 0s 21ms/step
# Class: confused
# Confidence Score: 0.6197652
# 1
# 1/1 [==============================] - 0s 24ms/step
# Class: confused
# Confidence Score: 0.96388984
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.96388984
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.9164427
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.9243616
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.9680568
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.9970893
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.91563517
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.99103385
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.8402065
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.993936
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.9593751
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.95999545
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.6736895
# 1
# 1/1 [==============================] - 0s 25ms/step
# Class: focused
# Confidence Score: 0.7974001
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.9363409
# 1
# 1/1 [==============================] - 0s 21ms/step
# Class: focused
# Confidence Score: 0.89198124
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.9674035
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.8929867
# 0
# 1/1 [==============================] - 0s 21ms/step
# Class: focused
# Confidence Score: 0.6918501
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.59511524
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.9516271
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.94483286
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.9246717
# 0
# 1/1 [==============================] - 0s 21ms/step
# Class: focused
# Confidence Score: 0.88624185
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.9397756
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.9249774
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.7499629
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.8397723
# 0
# 1/1 [==============================] - 0s 25ms/step
# Class: focused
# Confidence Score: 0.9347424
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.89948153
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.963647
# 0
# 1/1 [==============================] - 0s 21ms/step
# Class: focused
# Confidence Score: 0.9042965
# 0
# 1/1 [==============================] - 0s 24ms/step
# Class: focused
# Confidence Score: 0.6005475
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.89030683
# 0
# 1/1 [==============================] - 0s 31ms/step
# Class: focused
# Confidence Score: 0.7695326
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.5437046
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.68652433
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.7711395
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.8575629
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.8490886
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.9607171
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.49930573
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.8600568
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.9211235
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.92847043
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.9263668
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.9278451
# 1
# 1/1 [==============================] - 0s 21ms/step
# Class: confused
# Confidence Score: 0.94514906
# 1
# 1/1 [==============================] - 0s 21ms/step
# Class: confused
# Confidence Score: 0.80290556
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.98835874
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.88294286
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.985015
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.985015
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.9857606
# 1
# 1/1 [==============================] - 0s 21ms/step
# Class: confused
# Confidence Score: 0.91859204
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.89382493
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.8899721
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.5721875
# 1/1 [==============================] - 0s 21ms/step
# Class: confused
# Confidence Score: 0.70172435
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.98533916
# 1
# 1/1 [==============================] - 0s 24ms/step
# Class: confused
# Confidence Score: 0.97388047
# 1
# 1/1 [==============================] - 0s 24ms/step
# Class: focused
# Confidence Score: 0.555436
# 1/1 [==============================] - 0s 24ms/step
# Class: confused
# Confidence Score: 0.9519179
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.87840444
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.9558169
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.5491474
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.5491474
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.5012614
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.902016
# 1
# 1/1 [==============================] - 0s 26ms/step
# Class: focused
# Confidence Score: 0.7065832
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.9653207
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.94411033
# 1
# 1/1 [==============================] - 0s 24ms/step
# Class: focused
# Confidence Score: 0.89479965
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.9491587
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.97523195
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.8344019
# 0
# 1/1 [==============================] - 0s 21ms/step
# Class: focused
# Confidence Score: 0.75197583
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.91538197
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.86472875
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.9527638
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.87760323
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.93699646
# 0
# 1/1 [==============================] - 0s 25ms/step
# Class: focused
# Confidence Score: 0.8349824
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.98039323
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.98078763
# 0
# 1/1 [==============================] - 0s 25ms/step
# Class: focused
# Confidence Score: 0.98078763
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.51953876
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.62751186
# 0
# 1/1 [==============================] - 0s 27ms/step
# Class: focused
# Confidence Score: 0.9112648
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.8975373
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.9079041
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.7780306
# 0
# 1/1 [==============================] - 0s 24ms/step
# Class: focused
# Confidence Score: 0.9672363
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.9094356
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.92465085
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.9760149
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.671899
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.53043205
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.6131237
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.76792955
# 0
# 1/1 [==============================] - 0s 21ms/step
# Class: focused
# Confidence Score: 0.76792955
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.7990322
# 0
# 1/1 [==============================] - 0s 25ms/step
# Class: confused
# Confidence Score: 0.67190975
# 0
# 1/1 [==============================] - 0s 24ms/step
# Class: focused
# Confidence Score: 0.5520764
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.9378588
# 0
# 1/1 [==============================] - 0s 24ms/step
# Class: focused
# Confidence Score: 0.7284541
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.6350443
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.7641855
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.61667264
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.72654676
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.7759701
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.496456
# 1/1 [==============================] - 0s 24ms/step
# Class: focused
# Confidence Score: 0.5917566
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.46325815
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.62181896
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.71525884
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.60031563
# 0
# 1/1 [==============================] - 0s 24ms/step
# Class: confused
# Confidence Score: 0.5738327
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.51687336
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.62785774
# 0
# 1/1 [==============================] - 0s 21ms/step
# Class: focused
# Confidence Score: 0.5715248
# 1/1 [==============================] - 0s 21ms/step
# Class: confused
# Confidence Score: 0.92545444
# 0
# 1/1 [==============================] - 0s 24ms/step
# Class: confused
# Confidence Score: 0.9263362
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.89756286
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.8851079
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.8519731
# 1
# 1/1 [==============================] - 0s 24ms/step
# Class: confused
# Confidence Score: 0.8519731
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.7361176
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.81504536
# 1
# 1/1 [==============================] - 0s 21ms/step
# Class: confused
# Confidence Score: 0.64453465
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.6018546
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.5858876
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.619519
# 1
# 1/1 [==============================] - 0s 24ms/step
# Class: confused
# Confidence Score: 0.71539694
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.6307241
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.8259755
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.7282
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.82794034
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.50171876
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.97937244
# 1
# 1/1 [==============================] - 0s 24ms/step
# Class: confused
# Confidence Score: 0.97937244
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.6771011
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.5594295
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.7286661
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.5645006
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.80054235
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.71613777
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.533018
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.71317536
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.72307056
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.69995433
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.49151495
# 1/1 [==============================] - 0s 25ms/step
# Class: focused
# Confidence Score: 0.5800683
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.74392253
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.7730737
# 1
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.68738925
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.60582376
# 1
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.70887053
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.8553902
# 0
# 1/1 [==============================] - 0s 24ms/step
# Class: focused
# Confidence Score: 0.77148366
# 0
# 1/1 [==============================] - 0s 24ms/step
# Class: focused
# Confidence Score: 0.8837934
# 0
# 1/1 [==============================] - 0s 24ms/step
# Class: focused
# Confidence Score: 0.958507
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.8733345
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.9275789
# 0
# 1/1 [==============================] - 0s 24ms/step
# Class: focused
# Confidence Score: 0.927168
# 0
# 1/1 [==============================] - 0s 24ms/step
# Class: focused
# Confidence Score: 0.8817135
# 0
# 1/1 [==============================] - 0s 25ms/step
# Class: focused
# Confidence Score: 0.9435308
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.6974521
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.86692524
# 0
# 1/1 [==============================] - 0s 25ms/step
# Class: focused
# Confidence Score: 0.8057475
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.74274486
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.50839114
# 1/1 [==============================] - 0s 30ms/step
# Class: focused
# Confidence Score: 0.68722886
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: focused
# Confidence Score: 0.61016107
# 0
# 1/1 [==============================] - 0s 21ms/step
# Class: focused
# Confidence Score: 0.7003569
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.5026792
# 1/1 [==============================] - 0s 25ms/step
# Class: confused
# Confidence Score: 0.53752965
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.6409269
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.6409269
# 0
# 1/1 [==============================] - 0s 25ms/step
# Class: focused
# Confidence Score: 0.7589658
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.59660274
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.62399364
# 0
# 1/1 [==============================] - 0s 22ms/step
# Class: confused
# Confidence Score: 0.81246465
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: focused
# Confidence Score: 0.6988291
# 0
# 1/1 [==============================] - 0s 23ms/step
# Class: confused
# Confidence Score: 0.4215269
# 1/1 [==============================] - 0s 24ms/step
# Class: confused
# Confidence Score: 0.83611274
# 0
# 1/1 [==============================] - 0s 24ms/step
# Class: focused
# Confidence Score: 0.93770313
# 0
# 1/1 [==============================] - 0s 24ms/step
# Class: focused
# Confidence Score: 0.96097386
# 0
# 1/1 [==============================] - 0s 24ms/step
# Class: focused
# Confidence Score: 0.7783669
# 0
# 1/1 [==============================] - 0s 24ms/step
# Class: focused
# Confidence Score: 0.94845885
# 0
